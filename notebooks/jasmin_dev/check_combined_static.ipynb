# %%
import intake
cat = intake.open_catalog('https://raw.githubusercontent.com/digital-earths-global-hackathon/catalog/7582286a5eb68dab59174897e303eb8d7fbd61e2/catalog.yaml')['online']
ds = cat['um_glm_n2560_RAL3p3'].to_dask()
ds[['tas', 'orog', 'sftlf']]
# Out:
# /home/users/mmuetz/miniforge3/envs/hackathon_env/lib/python3.12/site-packages/intake_xarray/base.py:21: FutureWarning: The return type of `Dataset.dims` will be changed to return a set of dimension names in future, in order to be more consistent with `DataArray.dims`. To access a mapping from dimension names to lengths, please use `Dataset.sizes`.
#   'dims': dict(self._ds.dims),
# <xarray.Dataset> Size: 33GB
# Dimensions:  (time: 10489, cell: 786432)
# Coordinates:
#   * cell     (cell) int64 6MB 0 1 2 3 4 5 ... 786427 786428 786429 786430 786431
#     crs      float64 8B ...
#   * time     (time) datetime64[ns] 84kB 2020-01-20 ... 2021-04-01
# Data variables:
#     tas      (time, cell) float32 33GB dask.array<chunksize=(16, 65536), meta=np.ndarray>
#     orog     (cell) float64 6MB dask.array<chunksize=(49152,), meta=np.ndarray>
#     sftlf    (cell) float64 6MB dask.array<chunksize=(49152,), meta=np.ndarray>
# Attributes:
# ...
