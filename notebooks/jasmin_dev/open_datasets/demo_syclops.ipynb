# %%
import pandas as pd

# %%
baseurl = 'https://hackathon-o.s3-ext.jc.rl.ac.uk/sim-data/analysis/'

# %%
relurl = 'syclops/TCat/track_data/5km-RAL3p3/n2560RAL3p3regrid_tracks_20200201-20210111_6h_syclops_psl.csv'
df = pd.read_csv(baseurl + relurl)
df
# Out:
#        track_id   year   month   day   hour     i     j         lon  \
# 0             0   2020       2     1      6  1088   307  153.070312
# 1             0   2020       2     1     12  1116   291  157.007812
# 2             0   2020       2     1     18  1115   296  156.867188
# 3             0   2020       2     2      0  1133   283  159.398438
# 4             0   2020       2     2      6  1151   301  161.929688
# ...         ...    ...     ...   ...    ...   ...   ...         ...
# 51333      3310   2021       1    18     18  1224  1388  172.195312
# 51334      3310   2021       1    19      0  1249  1416  175.710937
# 51335      3310   2021       1    19      6  1268  1436  178.382812
# 51336      3310   2021       1    19     12  1283  1443  180.492188
# 51337      3310   2021       1    19     18  1307  1451  183.867188
#
#              lat      MSLP  ...   LOWTKCC   Z500CC   VO500AVG   RH100MAX  \
# 0     -61.171875  96486.75  ...     -5.25    22.50  -0.000071      0.500
# ...

# %%
relurl = 'syclops/TCat/track_data/5km-RAL3p3/n2560RAL3p3regrid_tracks_20200201-20201101_6h_tc_psl.csv'
df2 = pd.read_csv(baseurl + relurl)
df2
# Out:
#       track_id   year   month   day   hour     i    j         lon        lat  \
# 0            0   2020       2     5      0   548  814   77.132812 -13.640625
# 1            0   2020       2     5      6   548  811   77.132812 -13.921875
# 2            0   2020       2     5     12   548  809   77.132812 -14.109375
# 3            0   2020       2     5     18   547  806   76.992188 -14.390625
# 4            0   2020       2     6      0   548  807   77.132812 -14.296875
# ...        ...    ...     ...   ...    ...   ...  ...         ...        ...
# 2393       101   2020      11     6     12  1816  532  255.445312 -40.078125
# 2394       101   2020      11     6     18  1829  537  257.273438 -39.609375
# 2395       101   2020      11     7      0  1844  538  259.382812 -39.515625
# 2396       101   2020      11     7      6  1853  545  260.648438 -38.859375
# 2397       101   2020      11     7     12  1871  542  263.179688 -39.140625
#
# ...
