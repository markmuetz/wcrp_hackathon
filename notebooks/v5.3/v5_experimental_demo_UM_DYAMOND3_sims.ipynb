# %%
import math as maths

import cartopy.crs as ccrs
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import xarray as xr

import easygems.healpix as egh
# Out:
# /home/users/mmuetz/miniforge3/envs/hackathon_env/lib/python3.12/site-packages/pyproj/network.py:59: UserWarning: pyproj unable to set PROJ database path.
#   _set_context_ca_bundle_path(ca_bundle_path)

# %%
ds = xr.open_dataset('http://hackathon-o.s3.jc.rl.ac.uk/sim-data/dev/v5.3/glm.n2560_RAL3p3/um.PT3H.hp_z10.zarr', engine='zarr')

# %%
ds.hus.isel(time=0).mean(dim='cell').plot()

# %%
ds5p2 = xr.open_dataset('http://hackathon-o.s3.jc.rl.ac.uk/sim-data/dev/v5.2/glm.n2560_RAL3p3/um.PT3H.hp_z10.zarr', engine='zarr')

# %%
ds5p2.hus.isel(time=0).mean(dim='cell').plot()

# %%
ds5 = xr.open_dataset('http://hackathon-o.s3.jc.rl.ac.uk/sim-data/dev/v5/glm.n2560_RAL3p3/um.PT3H.hp_z10.zarr', engine='zarr')

# %%
ds5.hus.isel(time=0).mean(dim='cell').plot()

# %%
ds.isel(time=1).clw.mean(dim='cell').plot()

# %%
ds5.isel(time=1).clw.mean(dim='cell').plot()

# %%
ds5p2.isel(time=1).clw.mean(dim='cell').plot()
